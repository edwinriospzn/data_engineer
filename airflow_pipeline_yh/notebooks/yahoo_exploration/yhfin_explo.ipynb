# %%
import yfinance as yf
import pandas as pd

tickers = ["AAPL", "NVDA"]

df = yf.download(
    tickers=tickers,
    period="5d",
    interval="1m",
    group_by="ticker"
)

# Convert to long format with a ticker column
if isinstance(df.columns, pd.MultiIndex):
    df = df.stack(level=0).rename_axis(index=["Date", "ticker"]).reset_index()

# Optional: keep only the columns you want
# df = df[["Date", "ticker", "Close"]]

df.head()
# Out:
# [*********************100%***********************]  2 of 2 completed
# /tmp/ipykernel_79045/3833360365.py:15: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df = df.stack(level=0).rename_axis(index=["Date", "ticker"]).reset_index()
# Price                      Date ticker        Open        High         Low  \
# 0     2026-06-22 09:30:00-04:00   AAPL  297.500000  299.829987  297.500000
# 1     2026-06-22 09:30:00-04:00   NVDA  211.445007  211.990005  211.089996
# 2     2026-06-22 09:31:00-04:00   AAPL  299.334991  300.320007  298.980011
# 3     2026-06-22 09:31:00-04:00   NVDA  211.614395  211.684998  210.789993
# 4     2026-06-22 09:32:00-04:00   AAPL  300.140015  300.329987  299.615509
#
# Price       Close   Volume
# 0      299.309998  1447951
# 1      211.600006  6364924
# 2      300.154999   294971
# 3      211.093307   766563
# 4      300.000000   189758

# %%
import yfinance as yf

# Example: get fundamental data for each ticker
for ticker in ["AAPL", "NVDA"]:
    stock = yf.Ticker(ticker)
    info = stock.info
    print(ticker)
    print("Market Cap:", info.get("marketCap"))
    print("PE Ratio:", info.get("trailingPE"))
    print("Dividend Yield:", info.get("dividendYield"))
    print("Sector:", info.get("sector"))
    print("-" * 40)

# If you want a table, collect them into a DataFrame
fundamentals = []
for ticker in ["AAPL", "NVDA"]:
    stock = yf.Ticker(ticker)
    info = stock.info
    fundamentals.append({
        "ticker": ticker,
        "marketCap": info.get("marketCap"),
        "trailingPE": info.get("trailingPE"),
        "dividendYield": info.get("dividendYield"),
        "sector": info.get("sector")
    })

fundamentals_df = pd.DataFrame(fundamentals)
fundamentals_df
# Out:
# AAPL
# Market Cap: 4124944105472
# PE Ratio: 34.042423
# Dividend Yield: 0.39
# Sector: Technology
# ----------------------------------------
# NVDA
# Market Cap: 4698508099584
# PE Ratio: 29.661299
# Dividend Yield: 0.51
# Sector: Technology
# ----------------------------------------
#   ticker      marketCap  trailingPE  dividendYield      sector
# 0   AAPL  4124944105472   34.042423           0.39  Technology
# 1   NVDA  4698508099584   29.661299           0.51  Technology
