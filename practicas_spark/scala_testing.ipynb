// %%
// Usar Spark 3.4.0 en lugar de 3.5.1
import $ivy.`org.apache.spark::spark-sql:3.4.0`
import org.apache.spark.sql._

val spark = SparkSession.builder()
  .master("local[*]")
  .appName("Spark-In-Jupyter")
  .config("spark.driver.extraJavaOptions", 
    "--add-exports=java.base/sun.nio.ch=ALL-UNNAMED " +
    "--add-exports=java.base/sun.nio.ch=ALL-UNNAMED")
  .config("spark.executor.extraJavaOptions", 
    "--add-exports=java.base/sun.nio.ch=ALL-UNNAMED")
  .getOrCreate()

println(s"¡Éxito! Ejecutando Spark versión: ${spark.version}")

// Prueba rápida
val data = Seq((1, "a"), (2, "b"), (3, "c"))
val df = spark.createDataFrame(data).toDF("id", "value")
df.show()

require(df.count() == 3, s"Esperaba 3 filas, encontró ${df.count()}")
require(df.filter("id > 1").count() == 2, "La consulta filtrada no devolvió 2 filas")

println("✅ Prueba Scala completada: DataFrame creado y validado correctamente.")
// Out:
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/spark/spark-sql_2.13/3.4.0/spark-sql_2.13-3.4.0.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/spark/spark-parent_2.13/3.4.0/spark-parent_2.13-3.4.0.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/orc/orc-core/1.8.3/orc-core-1.8.3.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/spark/spark-tags_2.13/3.4.0/spark-tags_2.13-3.4.0.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/parquet/parquet-column/1.12.3/parquet-column-1.12.3.pom
// ...
// Downloaded https://repo1.maven.org/maven2/com/google/protobuf/protobuf-java/2.5.0/protobuf-java-2.5.0.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/spark/spark-core_2.13/3.4.0/spark-core_2.13-3.4.0.pom
// Downloaded https://repo1.maven.org/maven2/org/apache/xbean/xbean-asm9-shaded/4.22/xbean-asm9-shaded-4.22.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/parquet/parquet-hadoop/1.12.3/parquet-hadoop-1.12.3.pom
// ...

// %%
System.getProperty("java.version")
// Out:
// res4: String = "17.0.19"
